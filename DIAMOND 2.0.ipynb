# %% [markdown]
# # Diamond Data preprocessing using Pipeline and ColumnTransformer

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler , PowerTransformer , OneHotEncoder , OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
diamond_data = pd.read_csv(r"C:\Users\user\Downloads\diamonds.csv\diamonds.csv")
diamond_data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
diamond_data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# droping unknown columns 

diamond_data.drop(columns = 'Unnamed: 0',inplace = True)

# %%
diamond_data.shape
# Out:
# (53940, 10)

# %%
# info of the data
diamond_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# checking null values

diamond_data.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
# basic stastistics of the data

diamond_data.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %% [markdown]
# # Spliting The Data Into Train And Test

# %%
X_Train , X_Test , Y_Train , Y_Test = train_test_split(diamond_data.drop('price',axis =1),
                                                       diamond_data['price'],
                                                       test_size = 0.20,
                                                       random_state = 100)

# %%
X_Train.shape , X_Test.shape , len(Y_Train) , len(Y_Test)
# Out:
# ((43152, 9), (10788, 9), 43152, 10788)

# %%
diamond_data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
X_Train_Odinal_catg  = ['cut']
X_Train_Nominal_catg = ['color','clarity']
X_Train_continous    = ['carat','depth','table','x','y','z']

# %% [markdown]
# # Continuous Columns Pipeline

# %%
cont_pipeline = Pipeline(steps = [
    
    ('SimpleImputer', SimpleImputer(strategy = 'median')),
    ('RobustScaler' , RobustScaler()),
    ('PowerTransformer' , PowerTransformer())
    
])

# %% [markdown]
# # Categorical Odinal Column Pipeline

# %%
diamond_data['cut'].value_counts(normalize = True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
cat_pipeline_ordinal = Pipeline(steps = [
    
    ('SimpleImputer' , SimpleImputer(strategy = 'most_frequent')),
    ('OrdinalEncoder' , OrdinalEncoder(categories = [['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']]))
    
])

# %% [markdown]
# # Categorical Nominal Column Pipeline

# %%
cat_pipeline_nominal = Pipeline(steps =[
    
    ('SimpleImputer' , SimpleImputer(strategy = 'most_frequent')),
    ('OneHotEncoder' , OneHotEncoder(sparse_output = False , drop = 'first'))
    
])

# %% [markdown]
# # ColumnTransformer To Combine All The Pipelines

# %%
pre_col_Transformer = ColumnTransformer(transformers = [
    ('cat_pipeline_ordinal' , cat_pipeline_ordinal , X_Train_Odinal_catg),
    ('cat_pipeline_nominal' , cat_pipeline_nominal , X_Train_Nominal_catg),
    ('cont_pipeline' , cont_pipeline , X_Train_continous),
    
],remainder = 'passthrough')

# %% [markdown]
# # One Final Pipeline

# %%
final_pipeline = Pipeline(steps = [
    ('pre_col_Transformer' , pre_col_Transformer)
])

# %% [markdown]
# # Train Data Preprocessing

# %%
final_pipeline.fit_transform(X_Train)   # Array out_put of Train Data
# Out:
# array([[ 1.        ,  0.        ,  0.        , ...,  1.91252925,
#          1.83624526,  1.78259616],
#        [ 0.        ,  0.        ,  0.        , ...,  0.23735783,
#          0.31296124,  0.27883258],
#        [ 0.        ,  0.        ,  0.        , ..., -0.0339054 ,
#          0.00840006, -0.06939276],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ...,  0.54065231,
#          0.48842032,  0.49722525],
#        [ 1.        ,  0.        ,  0.        , ...,  1.04144837,
#          1.01317964,  1.07851817],
#        [ 0.        ,  0.        ,  0.        , ..., -1.14426046,
#         -1.20858117, -1.12102348]])

# %%
# pandas out_put of Train Data

X_Train_processed = pd.DataFrame(final_pipeline.fit_transform(X_Train) ,
                                 columns = final_pipeline.get_feature_names_out(),
                                 index = X_Train.index)

# %%
X_Train_processed.head()
# Out:
#        cat_pipeline_ordinal__cut  cat_pipeline_nominal__color_E  \
# 27187                        1.0                            0.0
# 3118                         0.0                            0.0
# 49238                        0.0                            0.0
# 53575                        0.0                            1.0
# 29795                        1.0                            0.0
#
#        cat_pipeline_nominal__color_F  cat_pipeline_nominal__color_G  \
# 27187                            0.0                            0.0
# 3118                             0.0                            0.0
# 49238                            0.0                            0.0
# 53575                            0.0                            0.0
# 29795                            0.0                            0.0
#
#        cat_pipeline_nominal__color_H  cat_pipeline_nominal__color_I  \
# 27187                            0.0                            1.0
# 3118                             1.0                            0.0
# 49238                            1.0                            0.0
# 53575                            0.0                            0.0
# 29795                            0.0                            0.0
#
#        cat_pipeline_nominal__color_J  cat_pipeline_nominal__clarity_IF  \
# 27187                            0.0                               0.0
# 3118                             0.0                               0.0
# 49238                            0.0                               0.0
# 53575                            0.0                               0.0
# 29795                            0.0                               0.0
#
#        cat_pipeline_nominal__clarity_SI1  cat_pipeline_nominal__clarity_SI2  \
# 27187                                1.0                                0.0
# 3118                                 0.0                                0.0
# 49238                                0.0                                0.0
# 53575                                0.0                                0.0
# 29795                                1.0                                0.0
#
#        cat_pipeline_nominal__clarity_VS1  cat_pipeline_nominal__clarity_VS2  \
# 27187                                0.0                                0.0
# 3118                                 0.0                                0.0
# 49238                                0.0                                0.0
# 53575                                0.0                                1.0
# 29795                                0.0                                0.0
#
#        cat_pipeline_nominal__clarity_VVS1  cat_pipeline_nominal__clarity_VVS2  \
# 27187                                 0.0                                 0.0
# 3118                                  0.0                                 1.0
# 49238                                 1.0                                 0.0
# 53575                                 0.0                                 0.0
# 29795                                 0.0                                 0.0
#
#        cont_pipeline__carat  cont_pipeline__depth  cont_pipeline__table  \
# 27187              1.872687             -1.081114              0.763221
# 3118               0.264667              0.158309             -0.662113
# 49238             -0.119152             -0.466062             -1.180787
# 53575              0.045189              0.651916             -0.607288
# 29795             -1.339541             -0.120638              0.358524
#
#        cont_pipeline__x  cont_pipeline__y  cont_pipeline__z
# 27187          1.912529          1.836245          1.782596
# 3118           0.237358          0.312961          0.278833
# 49238         -0.033905          0.008400         -0.069393
# 53575          0.104072          0.027100          0.122581
# 29795         -1.362183         -1.425600         -1.371937

# %% [markdown]
# # Test Data Preprocessing

# %%
final_pipeline.transform(X_Test)  # array out_put of Test Data
# Out:
# array([[ 0.        ,  1.        ,  0.        , ..., -0.25452028,
#         -0.27365404, -0.30064513],
#        [ 0.        ,  0.        ,  0.        , ...,  0.9378924 ,
#          0.98458125,  0.93261927],
#        [ 0.        ,  0.        ,  0.        , ..., -0.5577705 ,
#         -0.52187576, -0.42801054],
#        ...,
#        [ 0.        ,  1.        ,  0.        , ...,  0.08595299,
#          0.01776223,  0.12258051],
#        [ 1.        ,  1.        ,  0.        , ...,  0.47508878,
#          0.46387557,  0.27883258],
#        [ 1.        ,  0.        ,  0.        , ...,  0.66895839,
#          0.64800224,  0.52385557]])

# %%
# pandas out_put of Tast Data

X_Test_processed = pd.DataFrame(final_pipeline.transform(X_Test) ,
                                 columns = final_pipeline.get_feature_names_out(),
                                 index = X_Test.index)

# %%
X_Test_processed.head()
# Out:
#        cat_pipeline_ordinal__cut  cat_pipeline_nominal__color_E  \
# 52264                        0.0                            1.0
# 21073                        0.0                            0.0
# 42161                        0.0                            0.0
# 35974                        0.0                            0.0
# 7641                         1.0                            0.0
#
#        cat_pipeline_nominal__color_F  cat_pipeline_nominal__color_G  \
# 52264                            0.0                            0.0
# 21073                            0.0                            1.0
# 42161                            0.0                            1.0
# 35974                            1.0                            0.0
# 7641                             0.0                            1.0
#
#        cat_pipeline_nominal__color_H  cat_pipeline_nominal__color_I  \
# 52264                            0.0                            0.0
# 21073                            0.0                            0.0
# 42161                            0.0                            0.0
# 35974                            0.0                            0.0
# 7641                             0.0                            0.0
#
#        cat_pipeline_nominal__color_J  cat_pipeline_nominal__clarity_IF  \
# 52264                            0.0                               0.0
# 21073                            0.0                               0.0
# 42161                            0.0                               0.0
# 35974                            0.0                               0.0
# 7641                             0.0                               1.0
#
#        cat_pipeline_nominal__clarity_SI1  cat_pipeline_nominal__clarity_SI2  \
# 52264                                0.0                                0.0
# 21073                                0.0                                0.0
# 42161                                1.0                                0.0
# 35974                                0.0                                0.0
# 7641                                 0.0                                0.0
#
#        cat_pipeline_nominal__clarity_VS1  cat_pipeline_nominal__clarity_VS2  \
# 52264                                0.0                                1.0
# 21073                                1.0                                0.0
# 42161                                0.0                                0.0
# 35974                                1.0                                0.0
# 7641                                 0.0                                0.0
#
#        cat_pipeline_nominal__clarity_VVS1  cat_pipeline_nominal__clarity_VVS2  \
# 52264                                 0.0                                 0.0
# 21073                                 0.0                                 0.0
# 42161                                 0.0                                 0.0
# 35974                                 0.0                                 0.0
# 7641                                  0.0                                 0.0
#
#        cont_pipeline__carat  cont_pipeline__depth  cont_pipeline__table  \
# 52264             -0.330152             -0.189985             -0.092975
# 21073              0.942294             -0.189985             -1.180787
# 42161             -0.527575              1.007773              0.358524
# 35974             -0.852471             -0.808669             -0.607288
# 7641               0.287305              0.581044              0.358524
#
#        cont_pipeline__x  cont_pipeline__y  cont_pipeline__z
# 52264         -0.254520         -0.273654         -0.300645
# 21073          0.937892          0.984581          0.932619
# 42161         -0.557770         -0.521876         -0.428011
# 35974         -0.790641         -0.749498         -0.860004
# 7641           0.246087          0.295786          0.320543

# %% [markdown]
# # DIAGRAM PIPELINE

# %%
final_pipeline
# Out:
# Pipeline(steps=[('pre_col_Transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat_pipeline_ordinal',
#                                                   Pipeline(steps=[('SimpleImputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('OrdinalEncoder',
#                                                                    OrdinalEncoder(categories=[['Ideal',
#                                                                                                'Premium',
#                                                                                                'Very '
#                                                                                                'Good',
#                                                                                                'Good',
#                                                                                                'Fair']]))]),
#                                                   ['cut']),
#                                                  ('cat_pipeline_nominal',
#                                                   Pipeline(steps=[('SimpleImputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('OneHotEncoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['color', 'clarity']),
#                                                  ('cont_pipeline',
#                                                   Pipeline(steps=[('SimpleImputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('RobustScaler',
#                                                                    RobustScaler()),
#                                                                   ('PowerTransformer',
#                                                                    PowerTransformer())]),
#                                                   ['carat', 'depth', 'table',
#                                                    'x', 'y', 'z'])]))])
